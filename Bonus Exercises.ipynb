# %%
# libraries
import pandas as pd

# %%
location = 'C:/Users/unews/nss_data_science/data-question-1-unewsome/data/Age-specific fertility rates, Total fertility and .xls'
fert_df = pd.read_excel(location, skiprows=3)
fert_df.head(6)
# Out:
#        Country  ISO code       Period Reference  Unnamed: 4 Total fertility  \
# 0          NaN       NaN          NaN       Year     Period             NaN
# 1  Afghanistan       4.0  Around 1970       1973  1972-1973            8.21
# 2  Afghanistan       4.0           ..       1979        NaN            7.11
# 3  Afghanistan       4.0  Around 2005       2003  2000-2005            7.52
# 4  Afghanistan       4.0       Latest       2009  2007-2010            5.11
# 5      Albania       8.0  Around 1970       1970        NaN            5.16
#
#   Age-specific fertility rates Unnamed: 7 Unnamed: 8 Unnamed: 9     ...      \
# 0                        15-19      20-24      25-29      30-34     ...
# 1                          168        359        355        307     ...
# 2                          105        260        309        301     ...
# 3                          146        333        350        289     ...
# 4                           80        257        262        209     ...
# 5                           39        275        266        214     ...
#
#   Unnamed: 12 Mean age at childbearing    Source type               Source  \
# 0       45-49                       NaN           NaN                  NaN
# 1          81                        30        Survey  National statistics
# 2          ..                      30.7        Census  National statistics
# 3          ..                      30.1        Survey                  DHS
# 4          26                      29.1        Survey                  DHS
# 5          22                      29.7  Registration  National statistics
#
#                                          Survey name  \
# 0                                                NaN
# 1  Afghanistan 1972-1974 National Demographic and...
# 2                                                NaN
# 3                  Afghanistan 2010 Mortality Survey
# 4                  Afghanistan 2010 Mortality Survey
# 5                                                NaN
#
#         Note on country or population Note on age  \
# 0                                 NaN         NaN
# 1                                 NaN         NaN
# 2                                 NaN         NaN
# 3  Excluding areas in the South zone.         NaN
# 4  Excluding areas in the South zone.         NaN
# 5                                 NaN         NaN
#
#                                      Note on methods  \
# 0                                                NaN
# 1                                                NaN
# 2                                 Adjusted estimate.
# 3  Data pertain to the period of 5 to 9 years bef...
# 4                                                NaN
# 5                                                NaN
#
#   Note on population data used in denominator Unnamed: 21
# 0                                         NaN         NaN
# 1                                         NaN         NaN
# 2                                         NaN         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
# 5                                         NaN         NaN
#
# [6 rows x 22 columns]

# %%
fert_df.columns
##fert_df = fert_df[['Country', 'Reference ', 'Total fertility']]
#
# Out:
# Index(['Country', 'ISO code', 'Period', 'Reference ', 'Unnamed: 4',
#        'Total fertility', 'Age-specific fertility rates', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Mean age at childbearing ', 'Source type', 'Source', 'Survey name',
#        'Note on country or population', 'Note on age', 'Note on methods',
#        'Note on population data used in denominator', 'Unnamed: 21'],
#       dtype='object')

# %%
fert_df1 = fert_df[['Country', 'Reference ', 'Total fertility', 'Age-specific fertility rates','Unnamed: 7',
       'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
       'Mean age at childbearing ']]
fert_df1.columns = ['Country', 'Year', 'Total Fertility', 'Age-specific fertility rates 15-19', 'Age-specific fertility rates 20-24', 'Age-specific fertility rates 25-29', 'Age-specific fertility rates 30-34', 'Age-specific fertility rates 35 - 39', 'Age-specific fertility rates 40-45', 'Age-specific fertility rates 45-49', 'Mean Age at Childbearing' ]
fert_df1.head(1)
# Out:
#   Country  Year Total Fertility Age-specific fertility rates 15-19  \
# 0     NaN  Year             NaN                              15-19
#
#   Age-specific fertility rates 20-24 Age-specific fertility rates 25-29  \
# 0                              20-24                              25-29
#
#   Age-specific fertility rates 30-34 Age-specific fertility rates 35 - 39  \
# 0                              30-34                                35-39
#
#   Age-specific fertility rates 40-45 Age-specific fertility rates 45-49  \
# 0                              40-44                              45-49
#
#   Mean Age at Childbearing
# 0                      NaN

# %%
gdp_df = pd.read_csv('~/nss_data_science/data-question-1-unewsome/data/gdp_percapita.csv', nrows=6206)
internet_df = pd.read_csv('~/nss_data_science/data-question-1-unewsome/data/internet_use.csv', nrows=4495)
del gdp_df['Value Footnotes']
del internet_df['Value Footnotes']
gdp_df.columns=['Country','Year','GDP_Per_Capita']
internet_df.columns=['Country','Year','Internet_Users_Pct']
gdp_and_internet_use=pd.merge(gdp_df, internet_df, on = ['Country', 'Year'], how = 'outer')

# %%
fert_df1['Year']=fert_df1['Year'].apply(int)
fert_gdp_internet=pd.merge(gdp_and_internet_use, fert_df1, on = ['Country', 'Year'], how = 'outer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-ac836e47a76f> in <module>()
# ----> 1 fert_df1['Year']=fert_df1['Year'].apply(int)
#       2 fert_gdp_internet=pd.merge(gdp_and_internet_use, fert_df1, on = ['Country', 'Year'], how = 'outer')
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ValueError: invalid literal for int() with base 10: 'Year'

# %%
# ?pd.concat

# %%
fert_gdp_internet=pd.concat(gdp_and_internet_use, fert_df1, on = ['Country', 'Year'], how = 'outer')
fert_gdp_internet.head()
fert_gdp_internet.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-05a223b8b623> in <module>()
# ----> 1 fert_gdp_internet=pd.concat(gdp_and_internet_use, fert_df1, on = ['Country', 'Year'], how = 'outer')
#       2 fert_gdp_internet.head()
#       3 fert_gdp_internet.shape
#
# TypeError: concat() got an unexpected keyword argument 'on'
